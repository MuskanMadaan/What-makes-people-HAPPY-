# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:/Users/DELL/Downloads/2019.csv')

# %% [markdown]
# ### Dimension of data

# %%
df.shape
# Out:
# (156, 9)

# %% [markdown]
# ### Checking for missing values

# %%
df.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %% [markdown]
# ### Distribution

# %%
df.hist(bins=50,figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020DBF237160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020DC7289610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020DC72B7A60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020DC72E4EE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020DC731D370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020DC7349700>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020DC73497F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020DC7376CA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020DC73DA430>]],
#       dtype=object)

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %%
df=df.rename(columns={'Country or region':'Country'})

# %%
df.head()
# Out:
#    Overall rank      Country  Score  GDP per capita  Social support  \
# 0             1      Finland  7.769           1.340           1.587
# 1             2      Denmark  7.600           1.383           1.573
# 2             3       Norway  7.554           1.488           1.582
# 3             4      Iceland  7.494           1.380           1.624
# 4             5  Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %% [markdown]
# ### Top 10 happiest countries

# %%
df.groupby('Country')['Score'].max().sort_values(ascending=False).head(10).plot(kind='bar',figsize=(12,6),color='yellow')
plt.title('Top 10 happiest countries')
# Out:
# Text(0.5, 1.0, 'Top 10 happiest countries')

# %% [markdown]
# ### 10 saddest countries

# %%
df.groupby('Country')['Score'].max().sort_values(ascending=False).tail(10).plot(kind='bar',figsize=(12,6),color='yellow')
plt.title('10 saddest countries')
# Out:
# Text(0.5, 1.0, '10 saddest countries')

# %% [markdown]
# ### Top 20 countries with highest GDP per capita

# %%
df.groupby('Country')['GDP per capita'].max().sort_values(ascending=False).head(20).plot(kind='bar',figsize=(25,10),color='limegreen')
plt.title("Top 20 countries with highest GDP per capita")
# Out:
# Text(0.5, 1.0, 'Top 20 countries with highest GDP per capita')

# %% [markdown]
# ### 10 countries with lowest GDP

# %%
df.groupby('Country')['GDP per capita'].max().sort_values(ascending=False).tail(20).plot(kind='bar',figsize=(25,10),color='limegreen')
plt.title("20 countries with lowest GDP per capita")
# Out:
# Text(0.5, 1.0, '20 countries with lowest GDP per capita')

# %% [markdown]
# ### Top 20 countries with highest social support

# %%
df.groupby('Country')['Social support'].max().sort_values(ascending=False).head(20).plot(kind='bar',figsize=(20,6),color='cornflowerblue')
plt.title('Top 20 countries with highest social support')
# Out:
# Text(0.5, 1.0, 'Top 20 countries with highest social support')

# %% [markdown]
# ### 20 countries with lowest social support

# %%
df.groupby('Country')['Social support'].max().sort_values(ascending=False).tail(20).plot(kind='bar',figsize=(20,6),color='cornflowerblue')
plt.title('20 countries with lowest social support')
# Out:
# Text(0.5, 1.0, '20 countries with lowest social support')

# %% [markdown]
# ### Top 20 countries with high healthy life expectancy

# %%
df.groupby('Country')['Healthy life expectancy'].max().sort_values(ascending=False).head(20).plot(kind='bar',figsize=(20,6),color='aqua')
plt.title('Top 20 countries with high healthy life expectancy')
# Out:
# Text(0.5, 1.0, 'Top 20 countries with high healthy life expectancy')

# %% [markdown]
# ### 20 countries with lowest healthy life expectancy

# %%
df.groupby('Country')['Healthy life expectancy'].max().sort_values(ascending=False).tail(20).plot(kind='bar',figsize=(20,6),color='aqua')
plt.title('20 countries with lowest healthy life expectancy')
# Out:
# Text(0.5, 1.0, '20 countries with lowest healthy life expectancy')

# %% [markdown]
# ### Top 20 countries with high freedom to make life choices

# %%
df.groupby('Country')['Freedom to make life choices'].max().sort_values(ascending=False).head(20).plot(kind='bar',figsize=(20,6),color='plum')
plt.title('Top 20 countries with high freedom to make life choices')
# Out:
# Text(0.5, 1.0, 'Top 20 countries with high freedom to make life choices')

# %% [markdown]
# ### Top 20 countries with highest generosity

# %%
df.groupby('Country')['Generosity'].max().sort_values(ascending=False).head(20).plot(kind='bar', figsize=(20,6),color='red')
plt.title('Top 20 countries with highest generosity')
# Out:
# Text(0.5, 1.0, 'Top 20 countries with highest generosity')

# %% [markdown]
# ### 20 countries with lowest generosity

# %%
df.groupby('Country')['Generosity'].max().sort_values(ascending=False).tail(20).plot(kind='bar', figsize=(20,6),color='red')
plt.title('20 countries with lowest generosity')
# Out:
# Text(0.5, 1.0, '20 countries with lowest generosity')

# %% [markdown]
# ### Top 20 countries with highest perceptions of corruption

# %%
df.groupby('Country')['Perceptions of corruption'].max().sort_values(ascending=False).head(20).plot(kind='bar', figsize=(20,6),color='lime')
plt.title('Top 20 countries with highest perceptions of corruption')
# Out:
# Text(0.5, 1.0, 'Top 20 countries with highest perceptions of corruption')

# %% [markdown]
# ### 20 countries with lowest perceptions of corruption

# %%
df.groupby('Country')['Perceptions of corruption'].max().sort_values(ascending=False).tail(20).plot(kind='bar', figsize=(20,6),color='lime')
plt.title('20 countries with lowest perceptions of corruption')
# Out:
# Text(0.5, 1.0, '20 countries with lowest perceptions of corruption')

# %%
df.head()
# Out:
#    Overall rank      Country  Score  GDP per capita  Social support  \
# 0             1      Finland  7.769           1.340           1.587
# 1             2      Denmark  7.600           1.383           1.573
# 2             3       Norway  7.554           1.488           1.582
# 3             4      Iceland  7.494           1.380           1.624
# 4             5  Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %% [markdown]
# ### What makes the people happy

# %%
fig,axes = plt.subplots(nrows=3,ncols=2,figsize=(12,6),sharey='row',sharex='row')
axes[0,0].scatter(x=df['Social support'],y=df['Score'])
axes[0,0].set_xlabel('Social support')
axes[0,0].set_ylabel('Score')

axes[0,1].scatter(x=df['Healthy life expectancy'],y=df['Score'])
axes[0,1].set_xlabel('Healthy life expectancy')
axes[0,1].set_ylabel('Score')

axes[1,0].scatter(x=df['Freedom to make life choices'],y=df['Score'])
axes[1,0].set_xlabel('Freedom to make life choices')
axes[1,0].set_ylabel('Score')

axes[1,1].scatter(x=df['Generosity'],y=df['Score'])
axes[1,1].set_xlabel('Generosity')
axes[1,1].set_ylabel('Score')

axes[2,0].scatter(x=df['Perceptions of corruption'],y=df['Score'])
axes[2,0].set_xlabel('Preceptions of corruption')
axes[2,0].set_ylabel('Score')

axes[2,1].scatter(x=df['GDP per capita'],y=df['Score'])
axes[2,1].set_xlabel('GDP per capita')
axes[2,1].set_ylabel('Score')
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# ### So we can see that, except perception of corruption every other thing like social support, health life expectancy and so on makes people happy
